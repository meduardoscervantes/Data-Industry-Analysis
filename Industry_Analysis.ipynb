# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy
import matplotlib.style
# %matplotlib inline

# %%
table_2_path = "Resources/Table_2.csv"
table_2_df = pd.read_csv(table_2_path)
table_2_df
# Out:
#           2020 National Employment Matrix title  \
# 0                        Management occupations
# 1                                Top executives
# 2                              Chief executives
# 3               General and operations managers
# 4                                   Legislators
# ...                                         ...
# 1042    Pump operators, except wellhead pumpers
# 1043                           Wellhead pumpers
# 1044  Refuse and recyclable material collectors
# 1045          Tank car, truck, and ship loaders
# 1046         Material moving workers, all other
#
#      2020 National Employment Matrix code Occupation type Employment, 2020  \
# 0                                 11-0000         Summary         9,782.30
# 1                                 11-1000         Summary         2,756.60
# 2                                 11-1011       Line item            292.5
# 3                                 11-1021       Line item         2,411.90
# 4                                 11-1031       Line item             52.2
# ...                                   ...             ...              ...
# 1042                              53-7072       Line item             11.1
# 1043                              53-7073       Line item             13.6
# 1044                              53-7081       Line item            140.5
# 1045                              53-7121       Line item               13
# 1046                              53-7199       Line item             27.1
#
#      Employment, 2030 Employment change, 2020-30  \
# 0           10,689.10                      906.8
# 1            2,970.00                      213.5
# 2               275.7                      -16.8
# 3            2,638.20                      226.3
# 4                56.1                          4
# ...               ...                        ...
# 1042             12.5                        1.4
# 1043             14.8                        1.3
# 1044            157.2                       16.7
# 1045             13.6                        0.6
# 1046             29.6                        2.5
#
#       Percent employment change, 2020-30 Percent self employed, 2020  \
# 0                                    9.3                        13.1
# 1                                    7.7                         3.2
# 2                                   -5.7                          25
# 3                                    9.4                         0.7
# 4                                    7.6                           �
# ...                                  ...                         ...
# 1042                                12.6                         6.5
# 1043                                 9.4                         6.3
# 1044                                11.9                        12.9
# 1045                                 4.7                         2.4
# 1046                                 9.1                         2.2
#
#      Occupational openings, 2020-30 annual average Median annual wage 2020  \
# 0                                            904.4                  109760
# 1                                            251.4                  106180
# 2                                             17.5                  185950
# 3                                            229.6                  103650
# 4                                              4.3                   33200
# ...                                            ...                     ...
# 1042                                           1.4                   48090
# 1043                                           1.7                   60720
# 1044                                          21.4                   39100
# 1045                                           1.6                   45610
# 1046                                           3.6                   32850
#
#      Typical education needed for entry  \
# 0                                     �
# 1                                     �
# 2                     Bachelor's degree
# 3                     Bachelor's degree
# 4                     Bachelor's degree
# ...                                 ...
# 1042  High school diploma or equivalent
# 1043  High school diploma or equivalent
# 1044   No formal educational credential
# 1045   No formal educational credential
# 1046   No formal educational credential
#
#      Work experience in a related occupation  \
# 0                                          �
# 1                                          �
# 2                            5 years or more
# 3                            5 years or more
# 4                          Less than 5 years
# ...                                      ...
# 1042                                    None
# 1043                       Less than 5 years
# 1044                                    None
# 1045                                    None
# 1046                                    None
#
#      Typical on-the-job training needed to attain competency in the occupation
# 0                                                     �
# 1                                                     �
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1042                  Moderate-term on-the-job training
# 1043                  Moderate-term on-the-job training
# 1044                     Short-term on-the-job training
# 1045                     Short-term on-the-job training
# 1046                     Short-term on-the-job training
#
# [1047 rows x 13 columns]

# %%
df = table_2_df.loc[
    (table_2_df["2020 National Employment Matrix title"] == "Data scientists and mathematical science occupations, all other") | 
    (table_2_df["2020 National Employment Matrix title"] == "Database administrators and architects") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer and information research scientists") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer and information systems managers") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer and mathematical occupations") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer network architects") | 
    (table_2_df["2020 National Employment Matrix title"] == "Computer network support specialists") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer numerically controlled tool operators") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer numerically controlled tool programmers") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer programmers") |
    (table_2_df["2020 National Employment Matrix title"] == "Computer systems analysts") |
    (table_2_df["2020 National Employment Matrix title"] == "Data scientists and mathematical science occupations, all other") |
    (table_2_df["2020 National Employment Matrix title"] == "Database administrators and architects") 
]

# %%
df = df.astype({"2020 National Employment Matrix title": str, "Median annual wage 2020": float})
df
# Out:
#                  2020 National Employment Matrix title  \
# 13           Computer and information systems managers
# 77               Computer and mathematical occupations
# 80                           Computer systems analysts
# 82        Computer and information research scientists
# 84                Computer network support specialists
# 87                         Computer network architects
# 89              Database administrators and architects
# 91                                Computer programmers
# 100  Data scientists and mathematical science occup...
# 972     Computer numerically controlled tool operators
# 973   Computer numerically controlled tool programmers
#
#     2020 National Employment Matrix code Occupation type Employment, 2020  \
# 13                                Nov-21       Line item              482
# 77                               15-0000         Summary         5,225.00
# 80                               15-1211       Line item            607.8
# 82                               15-1221       Line item               33
# 84                               15-1231       Line item            189.8
# 87                               15-1241       Line item            165.2
# 89                               15-1245       Line item              168
# 91                               15-1251       Line item            185.7
# 100                              15-2098       Line item             63.2
# 972                              51-9161       Line item            158.4
# 973                              51-9162       Line item             27.1
#
#     Employment, 2030 Employment change, 2020-30  \
# 13             534.6                       52.7
# 77          5,959.90                      734.9
# 80             650.6                       42.8
# 82              40.2                        7.2
# 84               204                       14.2
# 87             174.2                          9
# 89             181.2                       13.2
# 91             167.3                      -18.3
# 100               83                       19.8
# 972            154.5                       -3.9
# 973             34.5                        7.4
#
#      Percent employment change, 2020-30 Percent self employed, 2020  \
# 13                                 10.9                         2.2
# 77                                 14.1                         9.7
# 80                                  7.0                         2.9
# 82                                 21.9                         3.7
# 84                                  7.5                         0.9
# 87                                  5.5                         2.1
# 89                                  7.8                        16.9
# 91                                 -9.9                         2.2
# 100                                31.4                         2.8
# 972                                -2.5                         1.9
# 973                                27.4                         1.9
#
#     Occupational openings, 2020-30 annual average  Median annual wage 2020  \
# 13                                           42.4                 151150.0
# 77                                          466.4                  91350.0
# 80                                           47.5                  93730.0
# 82                                            3.2                 126830.0
# 84                                           15.5                  65450.0
# 87                                             11                 116780.0
# 89                                           13.9                  98860.0
# 91                                            9.7                  89190.0
# 100                                           7.1                  98230.0
# 972                                          16.5                  42260.0
# 973                                           4.1                  57740.0
#
#     Typical education needed for entry  \
# 13                   Bachelor's degree
# 77                                   �
# 80                   Bachelor's degree
# 82                     Master's degree
# 84                  Associate's degree
# 87                   Bachelor's degree
# 89                   Bachelor's degree
# 91                   Bachelor's degree
# 100                  Bachelor's degree
# 972  High school diploma or equivalent
# 973      Postsecondary nondegree award
#
#     Work experience in a related occupation  \
# 13                          5 years or more
# 77                                        �
# 80                                     None
# 82                                     None
# 84                                     None
# 87                          5 years or more
# 89                                     None
# 91                                     None
# 100                                    None
# 972                                    None
# 973                                    None
#
#     Typical on-the-job training needed to attain competency in the occupation
# 13                                                None
# 77                                                   �
# 80                                                None
# 82                                                None
# 84                                                None
# 87                                                None
# 89                                                None
# 91                                                None
# 100                                               None
# 972                  Moderate-term on-the-job training
# 973                  Moderate-term on-the-job training

# %%
col = df[['2020 National Employment Matrix title','Median annual wage 2020']]
col = col.astype({"2020 National Employment Matrix title": str, "Median annual wage 2020": float})
col
#col.plot(kind ="bar", rot = 45)
#plt.show
# Out:
#                  2020 National Employment Matrix title  \
# 13           Computer and information systems managers
# 77               Computer and mathematical occupations
# 80                           Computer systems analysts
# 82        Computer and information research scientists
# 84                Computer network support specialists
# 87                         Computer network architects
# 89              Database administrators and architects
# 91                                Computer programmers
# 100  Data scientists and mathematical science occup...
# 972     Computer numerically controlled tool operators
# 973   Computer numerically controlled tool programmers
#
#      Median annual wage 2020
# 13                  151150.0
# 77                   91350.0
# 80                   93730.0
# 82                  126830.0
# 84                   65450.0
# 87                  116780.0
# 89                   98860.0
# 91                   89190.0
# 100                  98230.0
# 972                  42260.0
# 973                  57740.0

# %%
set_x = col["2020 National Employment Matrix title"]
set_y = col["Median annual wage 2020"]

#Establish dataframe with the values
plt.barh(set_x, set_y)

#Chart editing
plt.title("Average Annual Salary")
plt.xticks(rotation=90)
plt.xlabel("Average Salary ($)") 
plt.show()
